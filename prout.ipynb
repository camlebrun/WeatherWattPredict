# %%
import pandas as pd

# %%
file = pd.read_csv('data_departement_46.csv', sep=';')

# %%
file['TX'].isna().sum()
# Out:
# 563579

# %%
(563578/806266)*100
# Out:
# 69.89976012879124

# %%
file
# Out:
#         NUM_POSTE        NOM_USUEL        LAT       LON  ALTI  AAAAMMJJ    RR  \
# 0        46005001          ANGLARS  44.493333  1.208167   104  19890424   0.0
# 1        46005001          ANGLARS  44.493333  1.208167   104  19890425  14.6
# 2        46005001          ANGLARS  44.493333  1.208167   104  19890426   0.0
# 3        46005001          ANGLARS  44.493333  1.208167   104  19890427  10.0
# 4        46005001          ANGLARS  44.493333  1.208167   104  19890428   0.0
# ...           ...              ...        ...       ...   ...       ...   ...
# 806261   46332001  VIAZAC - LABOUD  44.662500  2.073833   394  20211227  40.1
# 806262   46332001  VIAZAC - LABOUD  44.662500  2.073833   394  20211228  16.2
# 806263   46332001  VIAZAC - LABOUD  44.662500  2.073833   394  20211229   5.6
# 806264   46332001  VIAZAC - LABOUD  44.662500  2.073833   394  20211230   0.0
# 806265   46332001  VIAZAC - LABOUD  44.662500  2.073833   394  20211231   0.0
#
# ...
