# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/camille/repo/projet_perso/elec/data/data_2010_2023.csv')
df
# Out:
#            NUM_POSTE NOM_USUEL        LAT       LON  AAAAMMJJ  TNTXM      DG  \
# 0          1014002.0    ARBENT  46.278167  5.669000  20100101    2.5   330.0
# 1          1014002.0    ARBENT  46.278167  5.669000  20100102   -4.0  1440.0
# 2          1014002.0    ARBENT  46.278167  5.669000  20100103   -6.3  1440.0
# 3          1014002.0    ARBENT  46.278167  5.669000  20100104   -3.6  1440.0
# 4          1014002.0    ARBENT  46.278167  5.669000  20100105   -2.1  1440.0
# ...              ...       ...        ...       ...       ...    ...     ...
# 16350828  95690001.0    WY-DIT  49.108167  1.830667  20231218    2.6   337.0
# 16350829  95690001.0    WY-DIT  49.108167  1.830667  20231219    6.6     0.0
# 16350830  95690001.0    WY-DIT  49.108167  1.830667  20231220    7.0     0.0
# 16350831  95690001.0    WY-DIT  49.108167  1.830667  20231221   10.1     0.0
# 16350832  95690001.0    WY-DIT  49.108167  1.830667  20231222    9.7     0.0
#
#             RR  FF2M
# 0         11.0   NaN
# ...

# %%
df['Date'] = pd.to_datetime(df['AAAAMMJJ'], format='%Y%m%d')

# Formater la colonne 'AAAAMMJJ' en "YYYY-MM-DD"
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')

# %%
df.drop(columns=['AAAAMMJJ'], inplace=True)

# %%
median_temp_france = df.groupby('Date')['TNTXM'].median().reset_index()

# %%
import plotly.express as px

fig = px.scatter(median_temp_france, x='Date', y='TNTXM',  title='Diagramme de dispersion de la température')
fig.show()
